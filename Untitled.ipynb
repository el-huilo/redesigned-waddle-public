# %%
#@title Main node
#@markdown Click start and wait until you see that it started on 127.0.0.1 in logs<br>Then go a bit higher, where cloudflared gave url, like some-thing.trycloudflare.com<br><br>You can also append to url /?__theme=light or =dark, dark is default
# !pip install invisible_watermark -q
# !pip install xformers -q
# !pip install gradio -q
# !pip install -U torchvision -q
# !pip install -U torchaudio -q
#!pip install -U gguf -q
#!pip install -U diffusers -q
# !sudo mkdir -p --mode=0755 /usr/share/keyrings
# !curl -fsSL https://pkg.cloudflare.com/cloudflare-main.gpg | sudo tee /usr/share/keyrings/cloudflare-main.gpg >/dev/null
# !echo 'deb [signed-by=/usr/share/keyrings/cloudflare-main.gpg] https://pkg.cloudflare.com/cloudflared jammy main' | sudo tee /etc/apt/sources.list.d/cloudflared.list
# !sudo apt-get update && sudo apt-get install cloudflared
# !git clone https://github.com/el-huilo/redesigned-waddle-public.git
# !python /content/redesigned-waddle-public/manag.py
